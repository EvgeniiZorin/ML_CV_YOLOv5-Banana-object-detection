# %%
import os
import torch
from PIL import Image
import matplotlib.pyplot as plt

import cv2
import numpy as np

# %%
print( os.getcwd() )

### Download YOLOv5 Github repo
if 'yolov5' not in os.listdir():
	# !git clone https://github.com/ultralytics/yolov5
	print(" > Successfully cloned github repo of YOLOv5!")
else:
	print(" > YOLOv5 repo already present.")

if os.path.basename(os.getcwd()) != 'yolov5':
	# %cd yolov5

print(f" > current dir: {os.getcwd()}")
# %pip install -qr requirements.txt
# %pip install -q roboflow
# Out:
# c:\Users\Data Science\Desktop\ML_CV_YOLOv5-Banana-object-detection
#  > YOLOv5 repo already present.
# c:\Users\Data Science\Desktop\ML_CV_YOLOv5-Banana-object-detection\yolov5
#  > current dir: c:\Users\Data Science\Desktop\ML_CV_YOLOv5-Banana-object-detection\yolov5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python detect.py --weights ../Final_model/best_params/best.pt --source ../bananas

# %%
img = cv2.imread('../bananas/banana4.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(3,3))
plt.imshow(img)
plt.show()

# %%
# Out:
# True

# %%
img = cv2.imread('../bananas/banana4.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(3,3))
plt.imshow(img)

# %%
img = cv2.imread('../bananas/banana4.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

model = torch.hub.load('ultralytics/yolov5', 'custom', path='../Final_model/best_params/best.pt') 
results = model(img)
img2 = results.render()

plt.imshow(img2[0])

cv2.imwrite('../asdf.jpg', cv2.cvtColor(img2[0], cv2.COLOR_RGB2BGR)) # If color scheme of loaded image is RGB
# Out:
# Using cache found in C:\Users\Data Science/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-4-26 Python-3.10.10 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1763224 parameters, 0 gradients, 4.1 GFLOPs
# Adding AutoShape...
# requirements: C:\Users\Data Science\.cache\torch\hub\requirements.txt not found, check failed.
# True

# %%
open('a.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 open('a.jpg')
#
# File c:\Users\Data Science\Desktop\ML_CV_YOLOv5-Banana-object-detection\.venv\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a.jpg'

# %%
import requests

url = 'http://127.0.0.1:8000/predict'
file = {'file': open('../a.jpg', 'rb')}
resp = requests.post(url=url, files=file)

with open('../soso.jpg', 'wb') as f:
    f.write(resp.content)
